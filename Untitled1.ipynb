# %%
import numpy as np
from numpy import linspace, sqrt, zeros, exp
import matplotlib.pyplot as plt

# %%
def get_dt(Lx, Ly, Nx, Ny, dt, q):
    """computes the grid"""
    # Find max(c) using a fake mesh and adapt dx to C and dt
    if isinstance(q, (float, int)):
        c_max = q**.5

        def q(x, y):
            return c_max**2

    elif callable(q):
        x_fake = np.linspace(0, Lx, 101)
        y_fake = np.linspace(0, Ly, 101)
        q_fake = q(*np.meshgrid(x_fake, y_fake))
        c_max = np.max(q_fake)**.5

    x = np.linspace(0, Lx, Nx+1)  # mesh points in x dir
    y = np.linspace(0, Ly, Ny+1)  # mesh points in y dir
    dx = 0 if len(x) == 1 else x[1] - x[0]
    dy = 0 if len(y) == 1 else y[1] - y[0]
    if dt <= 0:                # max time step?
        if dx == 0:
            dt = dy/c_max
        elif dy == 0:
            dt = dx/c_max
        else:
            dt = (1/float(c_max))*(1/sqrt(1/dx**2 + 1/dy**2))
        print("dt = ", dt)
    return x, y, dx, dy, dt

# %%
def scheme_ijn(u_n, u_nm1, dx, dy, dt,
               f, t_1, dtdx2, dtdy2, dt2,
               i, j, im1, ip1, jm1, jp1):
    """
    Right-hand side of finite difference at point [i,j].
    im1, ip1 denote i-1, i+1, resp. Similar for jm1, jp1.
    t_1 corresponds to u_n (previous time level relative to u).

    """
#    u_n = u[i, j, n]
#    u_nm1 = u[i, j, n-1]
    q = 1.0
    b = 0.0
    t1 = ((b*dt-2)*u_nm1[i, j] +
          2*dt2*f(dx*i, dy*j, t_1) +
          4*u_n[i, j])
    t2 = dtdx2*(-2* q*u_n[i, j] +
                q*u_n[im1, j] +
                q*u_n[ip1, j]) if u_n.shape[0] > 1 else 0
    t3 = dtdy2*(- 2*q*u_n[i, j] +
                q*u_n[i, jm1] +
                q*u_n[i, jp1]) if u_n.shape[1] > 1 else 0
    res = 1/(b*dt + 2)*(t1 + 2*t2 + 2*t3)
    return res


def scheme_ij1(u_n, u_nm1, dx, dy, dt,
               f, t_1, dtdx2, dtdy2, dt2,
               i, j, im1, ip1, jm1, jp1):
    """
    Right-hand side of finite difference at point [i,j] for n=1.
    im1, ip1 denote i-1, i+1, resp. Similar for jm1, jp1.
    t_1 corresponds to u_n (previous time level relative to u).

    """
#    u_n = u[i, j, n]
    q = 1.0
    b = 0.0
    V = 0.0
    t1 = (2*dt - b*dt2)*V + \
        dt2*f(dx*i, dy*j, 0) + \
        2*u_n[i, j]
    t2 = dtdx2*(- 2*q*u_n[i, j] + q*u_n[im1, j] + q*u_n[ip1, j]) if u_n.shape[0] > 1 else 0
    t3 = dtdy2*(- 2*q*u_n[i, j] + q*u_n[i, jm1] + q*u_n[i, jp1]) if u_n.shape[1] > 1 else 0
    res = 0.5 * (t1 + t2 + t3)
    return res

# %%
def scheme_vectorized_mesh(u, u_n, u_nm1, dx, dy, dt,
                           f, t_1, Nx, Ny, n,
                           dtdx2, dtdy2, dt2, bc):
    if n+1 == 1:
        scheme_ij = scheme_ij1
    elif n+1 > 1:
        scheme_ij = scheme_ijn
    else:
        raise ValueError("n must be larger than 0!")
    # # # # # # # # # # # INTERIOR POINTS # # # # # # # # # # # # # # # # # # #
    i = np.arange(0, Nx+1)  # the whole row
    j = np.arange(0, Ny+1)  # the whole column
    ii, jj = np.meshgrid(i, j)  # all rows and all columns
    im1 = ii-1
    ip1 = ii+1
    jm1 = jj-1
    jp1 = jj+1
    # Neumann conditions
    im1[:, 0] = 1
    ip1[:, Nx] = Nx - 1
    jm1[0, :] = 1
    jp1[Ny, :] = Ny - 1
    # flatten for "advanced indexing", see:
    # https://docs.scipy.org/doc/numpy-1.17.0/reference/arrays.indexing.html#advanced-indexing
    ii, jj = ii.ravel(), jj.ravel()
    im1, jm1 = im1.ravel(), jm1.ravel()
    ip1, jp1 = ip1.ravel(), jp1.ravel()
    u[ii, jj] = scheme_ij(u_n, u_nm1, dx, dy, dt,
                          f, t_1, dtdx2, dtdy2, dt2,
                          ii, jj, im1, ip1, jm1, jp1)
    return u

# %%
def solver(I, f, bc, Lx, Ly, Nx, Ny, dt, T,
           user_action=None,
           verbose=True):
    """
    Solve the 2D wave equation u_tt = u_xx + u_yy + f(x,t) on (0,L) with
    u = bc(x, y, t) on the boundary and initial condition du/dt = 0.

    Nx and Ny are the total number of grid cells in the x and y
    directions. The grid points are numbered as (0,0), (1,0), (2,0),
    ..., (Nx,0), (0,1), (1,1), ..., (Nx, Ny).

    dt is the time step. If dt<=0, an optimal time step is used.
    T is the stop time for the simulation.

    I, f, bc are functions: I(x,y), f(x,y,t), bc(x,y,t)

    user_action: function of (u, x, y, t, n) called at each time
    level (x and y are one-dimensional coordinate vectors).
    This function allows the calling code to plot the solution,
    compute errors, etc.

    verbose: true if a message at each time step is written,
    false implies no output during the simulation.
    """
    print("solving")
    scheme = scheme_vectorized_mesh

    x, y, dx, dy, dt = get_dt(Lx, Ly, Nx, Ny, dt, q=1.0)
    print(dt)
    #dt = dt/2
    Nt = int(round(T/float(dt)))
    t = linspace(0, T, Nt+1)   # mesh points in time

    dtdx2 = (dt/dx)**2 if dx > 0 else 0
    dtdy2 = (dt/dy)**2 if dy > 0 else 0
    dt2 = dt**2

    u_np1 = np.zeros((Nx+1, Ny+1), dtype=np.float64)   # solution array
    u_n = zeros((Nx+1, Ny+1), dtype=np.float64)   # solution at t-dt
    u_nm1 = zeros((Nx+1, Ny+1), dtype=np.float64)   # solution at t-2*dt
    u_np1.fill(np.nan)
    u_n.fill(np.nan)
    u_nm1.fill(np.nan)

    Ix = range(0, Nx+1)
    Iy = range(0, Ny+1)

    # Load initial condition into u_n
    for i in Ix:
        for j in Iy:
            u_np1[i, j] = I(dx*i, dy*j)
    if user_action is not None:
        user_action(u_np1, x, y, t, 0)
    u_n = u_np1.copy()

    # Special formula for first time step
    u_np1 = scheme(u_np1, u_n, u_nm1, dx, dy, dt,
                   f, t[0], Nx, Ny, 0,
                   dtdx2, dtdy2, dt2, bc)
    if user_action is not None:
        user_action(u_np1, x, y, t, 1)

    for n in range(1, Nt):
        u_nm1 = u_n.copy()
        u_n = u_np1.copy()
        u_np1 = scheme(u_np1, u_n, u_nm1, dx, dy, dt,
                       f, t[n], Nx, Ny, n,
                       dtdx2, dtdy2, dt2, bc)
        if user_action is not None:
            if user_action(u_np1, x, y, t, n+1):
                break
            #yield
    return dt  # dt might be computed in this function

# %%
def pulse(C=1, Nx=200, Ny=0, animate=True, version='vectorized', T=2,
          loc='center', pulse_tp='gaussian',
          medium=[0.7, 0.9], every_frame=1, sigma=0.1):
    """
    Various peaked-shaped initial conditions on [0,1].
    Wave velocity is decreased by the slowness_factor inside
    medium. The loc parameter can be 'center' or 'left',
    depending on where the initial pulse is to be located.
    The sigma parameter governs the width of the pulse.
    """
    # Use scaled parameters: L=1 for domain length, c_0=1
    # for wave velocity outside the domain.
    Lx = 1.0
    Ly = 1.0
    c_0 = 1.0
    xc = Lx/2
  #  xc = 0

    def I(x):
        _I_ = np.ones_like(x)
        _I_[abs(x-xc) > sigma] = 0
        return _I_



    def I_2D(x, y):
        if Ny == 0:
            l = x
        elif Nx == 0:
            l = y
        return I(l)

    def f(x, y, t):
        return 0


    q = 1.0
    dt = 0  # is calculated in the solver
    b = 0
    bc = {'N': None, 'W': None, 'E': None, 'S': None}
    ##############

    # initialize plot
    test_extent = (0, Lx, 0, Ly, 0, 1)
    x = np.linspace(0, Lx, Nx+1)  # mesh points in x dir
    y = np.linspace(0, Ly, Ny+1)  # mesh points in y dir
    X, Y = np.meshgrid(x, y)
    Z = I_2D(X, Y)

    last_solution = Z.T

    def action(u, x, y, t, n):
        print("action!", n)
        plt.plot(u, "ro")
        plt.plot(last_solution, "b.")
        plt.show()
        if n > 1:
            # every timestep exactly 2 cells change. If the wave is at the
            # boundary, only two cells change.
            msg = "the plug should travel exactly one cell per time step"
            cells_with_new_value = (u-last_solution) != 0
            print(np.sum(cells_with_new_value))

            #assert ((np.sum(cells_with_new_value) == 4) |
            #        (np.sum(cells_with_new_value) == 2) |
            #        (np.sum(cells_with_new_value) == 0)), msg
        last_solution[:, :] = u[:, :]
        #filename = os.path.join(out_path, '{}_{:06d}{}'.format(prefix, n, ext))
        #print(filename)
        return

    print("solve?")
    solver(I_2D, f, bc, Lx, Ly, Nx, Ny, dt, T,
           user_action=action)
    print("solved.")

# %%
pulse(Nx=100, Ny=0, pulse_tp='plug', T=5, medium=[-1, -1])
# Out:
# solve?
# solving
# dt =  0.01
# 0.01
# action! 0
# action! 1
# action! 2
# 4
# action! 3
# 4
# action! 4
# 4
# action! 5
# 4
# action! 6
# 4
# action! 7
# 4
# action! 8
# 4
# action! 9
# 4
# action! 10
# 4
# action! 11
# 3
# action! 12
# 4
# action! 13
# 4
# action! 14
# 4
# action! 15
# 4
# action! 16
# 4
# action! 17
# 4
# action! 18
# 4
# action! 19
# 4
# action! 20
# 4
# action! 21
# 4
# action! 22
# 4
# action! 23
# 4
# action! 24
# 4
# action! 25
# 4
# action! 26
# 4
# action! 27
# 4
# action! 28
# 4
# action! 29
# 4
# action! 30
# 4
# action! 31
# 4
# action! 32
# 4
# action! 33
# 4
# action! 34
# 4
# action! 35
# 4
# action! 36
# 4
# action! 37
# 4
# action! 38
# 4
# action! 39
# 4
# action! 40
# 4
# action! 41
# 4
# action! 42
# 4
# action! 43
# 4
# action! 44
# 4
# action! 45
# 4
# action! 46
# 4
# action! 47
# 4
# action! 48
# 4
# action! 49
# 4
# action! 50
# 4
# action! 51
# 4
# action! 52
# 4
# action! 53
# 4
# action! 54
# 4
# action! 55
# 4
# action! 56
# 4
# action! 57
# 4
# action! 58
# 4
# action! 59
# 4
# action! 60
# 4
# action! 61
# 4
# action! 62
# 4
# action! 63
# 4
# action! 64
# 4
# action! 65
# 4
# action! 66
# 4
# action! 67
# 4
# action! 68
# 4
# action! 69
# 4
# action! 70
# 4
# action! 71
# 4
# action! 72
# 4
# action! 73
# 4
# action! 74
# 4
# action! 75
# 4
# action! 76
# 4
# action! 77
# 4
# action! 78
# 4
# action! 79
# 4
# action! 80
# 4
# action! 81
# 4
# action! 82
# 4
# action! 83
# 4
# action! 84
# 4
# action! 85
# 4
# action! 86
# 4
# action! 87
# 4
# action! 88
# 4
# action! 89
# 4
# action! 90
# 3
# action! 91
# 4
# action! 92
# 4
# action! 93
# 4
# action! 94
# 4
# action! 95
# 4
# action! 96
# 4
# action! 97
# 4
# action! 98
# 4
# action! 99
# 4
# action! 100
# 4
# action! 101
# 4
# action! 102
# 4
# action! 103
# 4
# action! 104
# 4
# action! 105
# 4
# action! 106
# 4
# action! 107
# 4
# action! 108
# 4
# action! 109
# 4
# action! 110
# 4
# action! 111
# 3
# action! 112
# 4
# action! 113
# 4
# action! 114
# 4
# action! 115
# 4
# action! 116
# 4
# action! 117
# 4
# action! 118
# 4
# action! 119
# 4
# action! 120
# 4
# action! 121
# 4
# action! 122
# 4
# action! 123
# 4
# action! 124
# 4
# action! 125
# 4
# action! 126
# 4
# action! 127
# 4
# action! 128
# 4
# action! 129
# 4
# action! 130
# 4
# action! 131
# 4
# action! 132
# 4
# action! 133
# 4
# action! 134
# 4
# action! 135
# 4
# action! 136
# 4
# action! 137
# 4
# action! 138
# 4
# action! 139
# 4
# action! 140
# 4
# action! 141
# 4
# action! 142
# 4
# action! 143
# 4
# action! 144
# 4
# action! 145
# 4
# action! 146
# 4
# action! 147
# 4
# action! 148
# 4
# action! 149
# 4
# action! 150
# 4
# action! 151
# 4
# action! 152
# 4
# action! 153
# 4
# action! 154
# 4
# action! 155
# 4
# action! 156
# 4
# action! 157
# 4
# action! 158
# 4
# action! 159
# 4
# action! 160
# 4
# action! 161
# 4
# action! 162
# 4
# action! 163
# 4
# action! 164
# 4
# action! 165
# 4
# action! 166
# 4
# action! 167
# 4
# action! 168
# 4
# action! 169
# 4
# action! 170
# 4
# action! 171
# 4
# action! 172
# 4
# action! 173
# 4
# action! 174
# 4
# action! 175
# 4
# action! 176
# 4
# action! 177
# 4
# action! 178
# 4
# action! 179
# 4
# action! 180
# 4
# action! 181
# 4
# action! 182
# 4
# action! 183
# 4
# action! 184
# 4
# action! 185
# 4
# action! 186
# 4
# action! 187
# 4
# action! 188
# 4
# action! 189
# 4
# action! 190
# 3
# action! 191
# 4
# action! 192
# 4
# action! 193
# 4
# action! 194
# 4
# action! 195
# 4
# action! 196
# 4
# action! 197
# 4
# action! 198
# 4
# action! 199
# 4
# action! 200
# 4
# action! 201
# 4
# action! 202
# 4
# action! 203
# 4
# action! 204
# 4
# action! 205
# 4
# action! 206
# 4
# action! 207
# 4
# action! 208
# 4
# action! 209
# 4
# action! 210
# 4
# action! 211
# 3
# action! 212
# 4
# action! 213
# 4
# action! 214
# 4
# action! 215
# 4
# action! 216
# 4
# action! 217
# 4
# action! 218
# 4
# action! 219
# 4
# action! 220
# 4
# action! 221
# 4
# action! 222
# 4
# action! 223
# 4
# action! 224
# 4
# action! 225
# 4
# action! 226
# 4
# action! 227
# 4
# action! 228
# 4
# action! 229
# 4
# action! 230
# 4
# action! 231
# 4
# action! 232
# 4
# action! 233
# 4
# action! 234
# 4
# action! 235
# 4
# action! 236
# 4
# action! 237
# 4
# action! 238
# 4
# action! 239
# 4
# action! 240
# 4
# action! 241
# 4
# action! 242
# 4
# action! 243
# 4
# action! 244
# 4
# action! 245
# 4
# action! 246
# 4
# action! 247
# 4
# action! 248
# 4
# action! 249
# 4
# action! 250
# 4
# action! 251
# 4
# action! 252
# 4
# action! 253
# 4
# action! 254
# 4
# action! 255
# 4
# action! 256
# 4
# action! 257
# 4
# action! 258
# 4
# action! 259
# 4
# action! 260
# 4
# action! 261
# 4
# action! 262
# 4
# action! 263
# 4
# action! 264
# 4
# action! 265
# 4
# action! 266
# 4
# action! 267
# 4
# action! 268
# 4
# action! 269
# 4
# action! 270
# 4
# action! 271
# 4
# action! 272
# 4
# action! 273
# 4
# action! 274
# 4
# action! 275
# 4
# action! 276
# 4
# action! 277
# 4
# action! 278
# 4
# action! 279
# 4
# action! 280
# 4
# action! 281
# 4
# action! 282
# 4
# action! 283
# 4
# action! 284
# 4
# action! 285
# 4
# action! 286
# 4
# action! 287
# 4
# action! 288
# 4
# action! 289
# 4
# action! 290
# 3
# action! 291
# 4
# action! 292
# 4
# action! 293
# 4
# action! 294
# 4
# action! 295
# 4
# action! 296
# 4
# action! 297
# 4
# action! 298
# 4
# action! 299
# 4
# action! 300
# 4
# action! 301
# 4
# action! 302
# 4
# action! 303
# 4
# action! 304
# 4
# action! 305
# 4
# action! 306
# 4
# action! 307
# 4
# action! 308
# 4
# action! 309
# 4
# action! 310
# 4
# action! 311
# 3
# action! 312
# 4
# action! 313
# 4
# action! 314
# 4
# action! 315
# 4
# action! 316
# 4
# action! 317
# 4
# action! 318
# 4
# action! 319
# 4
# action! 320
# 4
# action! 321
# 4
# action! 322
# 4
# action! 323
# 4
# action! 324
# 4
# action! 325
# 4
# action! 326
# 4
# action! 327
# 4
# action! 328
# 4
# action! 329
# 4
# action! 330
# 4
# action! 331
# 4
# action! 332
# 4
# action! 333
# 4
# action! 334
# 4
# action! 335
# 4
# action! 336
# 4
# action! 337
# 4
# action! 338
# 4
# action! 339
# 4
# action! 340
# 4
# action! 341
# 4
# action! 342
# 4
# action! 343
# 4
# action! 344
# 4
# action! 345
# 4
# action! 346
# 4
# action! 347
# 4
# action! 348
# 4
# action! 349
# 4
# action! 350
# 4
# action! 351
# 4
# action! 352
# 4
# action! 353
# 4
# action! 354
# 4
# action! 355
# 4
# action! 356
# 4
# action! 357
# 4
# action! 358
# 4
# action! 359
# 4
# action! 360
# 4
# action! 361
# 4
# action! 362
# 4
# action! 363
# 4
# action! 364
# 4
# action! 365
# 4
# action! 366
# 4
# action! 367
# 4
# action! 368
# 4
# action! 369
# 4
# action! 370
# 4
# action! 371
# 4
# action! 372
# 4
# action! 373
# 4
# action! 374
# 4
# action! 375
# 4
# action! 376
# 4
# action! 377
# 4
# action! 378
# 4
# action! 379
# 4
# action! 380
# 4
# action! 381
# 4
# action! 382
# 4
# action! 383
# 4
# action! 384
# 4
# action! 385
# 4
# action! 386
# 4
# action! 387
# 4
# action! 388
# 4
# action! 389
# 4
# action! 390
# 3
# action! 391
# 4
# action! 392
# 4
# action! 393
# 4
# action! 394
# 4
# action! 395
# 4
# action! 396
# 4
# action! 397
# 4
# action! 398
# 4
# action! 399
# 4
# action! 400
# 4
# action! 401
# 4
# action! 402
# 4
# action! 403
# 4
# action! 404
# 4
# action! 405
# 4
# action! 406
# 4
# action! 407
# 4
# action! 408
# 4
# action! 409
# 4
# action! 410
# 4
# action! 411
# 3
# action! 412
# 4
# action! 413
# 4
# action! 414
# 4
# action! 415
# 4
# action! 416
# 4
# action! 417
# 4
# action! 418
# 4
# action! 419
# 4
# action! 420
# 4
# action! 421
# 4
# action! 422
# 4
# action! 423
# 4
# action! 424
# 4
# action! 425
# 4
# action! 426
# 4
# action! 427
# 4
# action! 428
# 4
# action! 429
# 4
# action! 430
# 4
# action! 431
# 4
# action! 432
# 4
# action! 433
# 4
# action! 434
# 4
# action! 435
# 4
# action! 436
# 4
# action! 437
# 4
# action! 438
# 4
# action! 439
# 4
# action! 440
# 4
# action! 441
# 4
# action! 442
# 4
# action! 443
# 4
# action! 444
# 4
# action! 445
# 4
# action! 446
# 4
# action! 447
# 4
# action! 448
# 4
# action! 449
# 4
# action! 450
# 4
# action! 451
# 4
# action! 452
# 4
# action! 453
# 4
# action! 454
# 4
# action! 455
# 4
# action! 456
# 4
# action! 457
# 4
# action! 458
# 4
# action! 459
# 4
# action! 460
# 4
# action! 461
# 4
# action! 462
# 4
# action! 463
# 4
# action! 464
# 4
# action! 465
# 4
# action! 466
# 4
# action! 467
# 4
# action! 468
# 4
# action! 469
# 4
# action! 470
# 4
# action! 471
# 4
# action! 472
# 4
# action! 473
# 4
# action! 474
# 4
# action! 475
# 4
# action! 476
# 4
# action! 477
# 4
# action! 478
# 4
# action! 479
# 4
# action! 480
# 4
# action! 481
# 4
# action! 482
# 4
# action! 483
# 4
# action! 484
# 4
# action! 485
# 4
# action! 486
# 4
# action! 487
# 4
# action! 488
# 4
# action! 489
# 4
# action! 490
# 3
# action! 491
# 4
# action! 492
# 4
# action! 493
# 4
# action! 494
# 4
# action! 495
# 4
# action! 496
# 4
# action! 497
# 4
# action! 498
# 4
# action! 499
# 4
# action! 500
# 4
# solved.

# %%
#pulse(Nx=0, Ny=100, pulse_tp='plug', T=5, medium=[-1, -1])
